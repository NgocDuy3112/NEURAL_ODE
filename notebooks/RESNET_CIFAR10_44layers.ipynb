# %% [markdown]
# # Loading necessary libraries

# %%
import os
import random
import tensorflow as tf
from tensorflow import keras
from keras import layers, Model
from keras.regularizers import l2
from tensorflow.keras.optimizers import SGD
from keras.losses import sparse_categorical_crossentropy
from keras.layers import (
    Dense, MaxPool2D, AveragePooling2D, Dropout, Flatten,
    Conv2D, Input, Add, BatchNormalization, Activation, Layer
)
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical, plot_model
from keras.datasets import cifar10
import keras.backend as K
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2

# %load_ext autoreload
# %autoreload 2

# %%
class CIFAR10Dataset():
    def __init__(self):
        (self.x_train, self.y_train), (self.x_test, self.y_test) = cifar10.load_data()
        self.classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
        print('CIFAR10 training data shape: ', self.x_train.shape)
        print('CIFAR10 training label shape: ', self.y_train.shape)
        print('CIFAR10 test data shape: ', self.x_test.shape)
        print('CIFAR10 test label shape: ', self.y_test.shape)

    def get_data(self, subtract_mean=True):
        num_classes = len(self.classes)
        x_train = self.x_train
        x_test = self.x_test

        x_train = x_train.astype('float16')
        y_train = to_categorical(self.y_train, num_classes)

        x_test = x_test.astype('float16')
        y_test = to_categorical(self.y_test, num_classes)

        if subtract_mean:
            x_train -= np.mean(x_train, axis=0)
            x_test -= np.mean(x_train, axis=0)

        return x_train, y_train, x_test, y_test

# %%
def conv2d_bn(x, filters, kernel_size, weight_decay=.0, strides=(1,1)):
    x_new = Conv2D(filters=filters,
                   kernel_size=kernel_size,
                   strides=strides,
                   padding='same',
                   use_bias=False,
                   kernel_regularizer=l2(weight_decay))(x)
    x_new = BatchNormalization()(x_new)
    return x_new

def conv2d_bn_relu(x, filters, kernel_size, weight_decay=.0, strides=(1,1)):
    x_new = conv2d_bn(x, filters, kernel_size, weight_decay, strides)
    x_new = Activation('relu')(x_new)
    return x_new

# %%
def plain_block(x, filters, kernel_size, weight_decay, downsample=True):
    if downsample:
        stride = 2
    else:
        stride = 1
    x_new = conv2d_bn_relu(x,
                           filters=filters,
                           kernel_size=kernel_size,
                           weight_decay=weight_decay,
                           strides=stride)
    x_new = conv2d_bn(x_new,
                      filters=filters,
                      kernel_size=kernel_size,
                      weight_decay=weight_decay,
                      strides=1)
    out = Activation('relu')(x_new)
    return out

def PlainNet(classes, name, input_shape, block_layers_num, weight_decay):
    input = Input(shape=input_shape)
    x = input

    # Conv 1
    x = conv2d_bn_relu(x,
                       filters=16,
                       kernel_size=(3,3),
                       weight_decay=weight_decay,
                       strides=(1,1))

    # Conv 2
    for i in range(block_layers_num):
        x = plain_block(x,
                        filters=16,
                        kernel_size=(3,3),
                        weight_decay=weight_decay,
                        downsample=False)

    # Conv 3
    x = plain_block(x,
                    filters=32,
                    kernel_size=(3,3),
                    weight_decay=weight_decay,
                    downsample=True)
    for i in range(block_layers_num - 1):
        x = plain_block(x,
                        filters=32,
                        kernel_size=(3,3),
                        weight_decay=weight_decay,
                        downsample=False)

    # Conv 4
    x = plain_block(x,
                    filters=64,
                    kernel_size=(3,3),
                    weight_decay=weight_decay,
                    downsample=True)
    for i in range(block_layers_num - 1):
        x = plain_block(x,
                        filters=64,
                        kernel_size=(3,3),
                        weight_decay=weight_decay,
                        downsample=False)

    # Classifier
    x = AveragePooling2D(pool_size=(8,8), padding='valid')(x)
    x = Flatten()(x)
    x = Dense(classes, activation='softmax')(x)
    model = Model(input, x, name=name)
    return model

# %%
def residual_block(x, filters, kernel_size, weight_decay, downsample=True):
    if downsample:
        res_x = conv2d_bn(x, filters, kernel_size=1, strides=2)
        stride = 2
    else:
        res_x = x
        stride = 1
    x_new = conv2d_bn_relu(x,
                           filters=filters,
                           kernel_size=kernel_size,
                           weight_decay=weight_decay,
                           strides=stride)
    x_new = conv2d_bn(x_new,
                      filters=filters,
                      kernel_size=kernel_size,
                      weight_decay=weight_decay,
                      strides=1)
    out = layers.add([res_x, x_new])
    out = Activation('relu')(out)
    return out

def ResNet(classes, name, input_shape, block_layers_num, weight_decay):
    input = Input(shape=input_shape)
    x = input

    # Conv 1
    x = conv2d_bn_relu(x,
                       filters=16,
                       kernel_size=(3,3),
                       weight_decay=weight_decay,
                       strides=(1,1))

    # Conv 2
    for i in range(block_layers_num):
        x = residual_block(x,
                           filters=16,
                           kernel_size=(3,3),
                           weight_decay=weight_decay,
                           downsample=False)

    # Conv 3
    x = residual_block(x,
                       filters=32,
                       kernel_size=(3,3),
                       weight_decay=weight_decay,
                       downsample=True)
    for i in range(block_layers_num - 1):
        x = residual_block(x,
                           filters=32,
                           kernel_size=(3,3),
                           weight_decay=weight_decay,
                           downsample=False)

    # Conv 4
    x = residual_block(x,
                       filters=64,
                       kernel_size=(3,3),
                       weight_decay=weight_decay,
                       downsample=True)
    for i in range(block_layers_num - 1):
        x = residual_block(x,
                           filters=64,
                           kernel_size=(3,3),
                           weight_decay=weight_decay,
                           downsample=False)

    # Classifier
    x = AveragePooling2D(pool_size=(8,8), padding='valid')(x)
    x = Flatten()(x)
    x = Dense(classes, activation='softmax')(x)
    model = Model(input, x, name=name)
    return model

# %%
def error_rate(y_true, y_pred):
    # Assuming y_true and y_pred are tensors of the same shape
    incorrect = tf.not_equal(tf.argmax(y_true, axis=-1), tf.argmax(y_pred, axis=-1))
    error_rate = tf.reduce_mean(tf.cast(incorrect, tf.float32))
    return error_rate

# %%
class CIFAR10Solver(object):
    def __init__(self, model, data):
        self.model = model
        self.X_train, self.Y_train, self.X_val, self.Y_val, self.X_test, self.Y_test = data

    def __on_epoch_end(self, epoch, logs=None):
        print(K.eval(self.model.optimizer.lr))

    def train(self, epochs=200, batch_size=128, data_augmentation=True, callbacks=None):
        if data_augmentation:
            # datagen
            datagen = ImageDataGenerator(
                featurewise_center=False,  # set input mean to 0 over the dataset
                samplewise_center=False,  # set each sample mean to 0
                featurewise_std_normalization=False,  # divide inputs by std of the dataset
                samplewise_std_normalization=False,  # divide each input by its std
                zca_whitening=False,  # apply ZCA whitening
                # rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
                width_shift_range=4,  # randomly shift images horizontally (fraction of total width)
                height_shift_range=4,  # randomly shift images vertically (fraction of total height)
                horizontal_flip=True,  # randomly flip images
                vertical_flip=False,  # randomly flip images
            )
            # (std, mean, and principal components if ZCA whitening is applied).
            # datagen.fit(x_train)
            print('train with data augmentation')
            train_gen = datagen.flow(self.X_train, self.Y_train, batch_size=batch_size)
            history = self.model.fit_generator(generator=train_gen,
                                               epochs=epochs,
                                               callbacks=callbacks,
                                               validation_data=(self.X_val, self.Y_val))
        else:
            print('train without data augmentation')
            history = self.model.fit(self.X_train, self.Y_train,
                                     batch_size=batch_size, epochs=epochs,
                                     callbacks=callbacks,
                                     validation_data=(self.X_val, self.Y_val))
        return history

    def test(self):
        loss, acc = self.model.evaluate(self.X_test, self.Y_test)
        print('test data loss:%.2f acc:%.4f' % (loss, acc))

# %%
cifar10_data = CIFAR10Dataset()
x_train, y_train, x_test, y_test = cifar10_data.get_data(subtract_mean=True)

x = np.concatenate((x_train, x_test))
y = np.concatenate((y_train, y_test))

# Check shape
print(x.shape) # (60000, 32, 32, 3)

# Split data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=10000, random_state=1234)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=5000, random_state=1234)

# Check shape
print(x_train.shape) # (45000, 32, 32, 3)

data = (x_train, y_train, x_val, y_val, x_test, y_test)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step
# CIFAR10 training data shape:  (50000, 32, 32, 3)
# CIFAR10 training label shape:  (50000, 1)
# CIFAR10 test data shape:  (10000, 32, 32, 3)
# CIFAR10 test label shape:  (10000, 1)
# (60000, 32, 32, 3)
# (45000, 32, 32, 3)

# %%
weight_decay = 1e-4
lr = 1e-1
num_classes = 10
EPOCHS = 100

# %%
tf.keras.backend.reset_uids()
plainnet44 = PlainNet(classes=num_classes, name='plainnet44', input_shape=(32, 32, 3), block_layers_num=7, weight_decay=weight_decay)
opt = SGD(lr=lr, momentum=0.9, nesterov=False)
plainnet44.compile(optimizer=opt,
                 loss=keras.losses.categorical_crossentropy,
                 metrics=[error_rate])
# plainnet20.summary()
plot_model(plainnet44, show_shapes=True, expand_nested=True)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
tf.keras.backend.reset_uids()
resnet44 = ResNet(classes=num_classes, name='resnet44', input_shape=(32, 32, 3), block_layers_num=7, weight_decay=weight_decay)
opt = SGD(lr=lr, momentum=0.9, nesterov=False)
resnet44.compile(optimizer=opt,
                 loss=keras.losses.categorical_crossentropy,
                 metrics=[error_rate])
# resnet20.summary()
plot_model(resnet44, show_shapes=True, expand_nested=True)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
def lr_scheduler(epoch):
    new_lr = lr
    if epoch <= int(0.5*EPOCHS):
        pass
    elif epoch > int(0.5*EPOCHS) and epoch <= int(0.75*EPOCHS):
        new_lr = lr * 0.1
    else:
        new_lr = lr * 0.01
    print('new lr:%.2e' % new_lr)
    return new_lr

# %%
def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # Create a sub-model that outputs the feature maps and final prediction
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Use GradientTape to record gradients
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)

        # If pred_index is not specified, use the predicted class index
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # Calculate gradients
    grads = tape.gradient(class_channel, last_conv_layer_output)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # Compute the heatmap
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # Normalise the heatmap
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)

    return heatmap.numpy()

# %%
reduce_lr_1 = LearningRateScheduler(lr_scheduler)
mc1 = keras.callbacks.ModelCheckpoint(filepath="plainnet44_cifar10.tf",
                                      monitor='val_loss',
                                      mode='min',
                                      verbose=0,
                                      save_best_only=True)
solver_plain_44 = CIFAR10Solver(plainnet44, data)
history_plain_44 = solver_plain_44.train(epochs=EPOCHS, batch_size=128, data_augmentation=True,
                                         callbacks=[reduce_lr_1, mc1])
# Out:
# train with data augmentation
# new lr:1.00e-01
# Epoch 1/100
# <ipython-input-7-fec8c7b98f6b>:28: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = self.model.fit_generator(generator=train_gen,
# 352/352 [==============================] - 74s 156ms/step - loss: 8.9682 - error_rate: 0.8088 - val_loss: 8.8642 - val_error_rate: 0.7982 - lr: 0.1000
# new lr:1.00e-01
# Epoch 2/100
# 352/352 [==============================] - 51s 146ms/step - loss: 8.1451 - error_rate: 0.7280 - val_loss: 7.7754 - val_error_rate: 0.7707 - lr: 0.1000
# new lr:1.00e-01
# Epoch 3/100
# 352/352 [==============================] - 50s 141ms/step - loss: 7.2403 - error_rate: 0.6913 - val_loss: 7.8154 - val_error_rate: 0.8014 - lr: 0.1000
# new lr:1.00e-01
# Epoch 4/100
# 352/352 [==============================] - 51s 144ms/step - loss: 6.4756 - error_rate: 0.6632 - val_loss: 6.2954 - val_error_rate: 0.6829 - lr: 0.1000
# new lr:1.00e-01
# Epoch 5/100
# 352/352 [==============================] - 55s 156ms/step - loss: 5.8009 - error_rate: 0.6356 - val_loss: 5.6810 - val_error_rate: 0.6608 - lr: 0.1000
# new lr:1.00e-01
# Epoch 6/100
# 352/352 [==============================] - 52s 148ms/step - loss: 5.2268 - error_rate: 0.6164 - val_loss: 5.2914 - val_error_rate: 0.6644 - lr: 0.1000
# new lr:1.00e-01
# Epoch 7/100
# 352/352 [==============================] - 52s 148ms/step - loss: 4.7116 - error_rate: 0.5912 - val_loss: 4.8320 - val_error_rate: 0.6678 - lr: 0.1000
# new lr:1.00e-01
# Epoch 8/100
# 352/352 [==============================] - 39s 110ms/step - loss: 4.2569 - error_rate: 0.5649 - val_loss: 4.9979 - val_error_rate: 0.7186 - lr: 0.1000
# new lr:1.00e-01
# Epoch 9/100
# 352/352 [==============================] - 54s 153ms/step - loss: 3.8552 - error_rate: 0.5418 - val_loss: 3.9557 - val_error_rate: 0.6188 - lr: 0.1000
# new lr:1.00e-01
# Epoch 10/100
# 352/352 [==============================] - 53s 152ms/step - loss: 3.4946 - error_rate: 0.5155 - val_loss: 3.7490 - val_error_rate: 0.5993 - lr: 0.1000
# new lr:1.00e-01
# Epoch 11/100
# 352/352 [==============================] - 38s 107ms/step - loss: 3.1755 - error_rate: 0.4922 - val_loss: 4.0871 - val_error_rate: 0.6459 - lr: 0.1000
# new lr:1.00e-01
# Epoch 12/100
# 352/352 [==============================] - 40s 112ms/step - loss: 2.8790 - error_rate: 0.4645 - val_loss: 4.7699 - val_error_rate: 0.6764 - lr: 0.1000
# new lr:1.00e-01
# Epoch 13/100
# 352/352 [==============================] - 54s 155ms/step - loss: 2.6260 - error_rate: 0.4378 - val_loss: 3.5528 - val_error_rate: 0.6290 - lr: 0.1000
# new lr:1.00e-01
# Epoch 14/100
# 352/352 [==============================] - 37s 105ms/step - loss: 2.3996 - error_rate: 0.4159 - val_loss: 3.9251 - val_error_rate: 0.6833 - lr: 0.1000
# new lr:1.00e-01
# Epoch 15/100
# 352/352 [==============================] - 53s 152ms/step - loss: 2.2042 - error_rate: 0.3959 - val_loss: 2.4759 - val_error_rate: 0.4767 - lr: 0.1000
# new lr:1.00e-01
# Epoch 16/100
# 352/352 [==============================] - 54s 152ms/step - loss: 2.0258 - error_rate: 0.3759 - val_loss: 2.3268 - val_error_rate: 0.4602 - lr: 0.1000
# new lr:1.00e-01
# Epoch 17/100
# 352/352 [==============================] - 53s 152ms/step - loss: 1.8947 - error_rate: 0.3614 - val_loss: 2.0687 - val_error_rate: 0.4295 - lr: 0.1000
# new lr:1.00e-01
# Epoch 18/100
# 352/352 [==============================] - 53s 151ms/step - loss: 1.7566 - error_rate: 0.3449 - val_loss: 1.9651 - val_error_rate: 0.4204 - lr: 0.1000
# new lr:1.00e-01
# Epoch 19/100
# 352/352 [==============================] - 39s 110ms/step - loss: 1.6429 - error_rate: 0.3332 - val_loss: 2.1707 - val_error_rate: 0.4835 - lr: 0.1000
# new lr:1.00e-01
# Epoch 20/100
# 352/352 [==============================] - 52s 149ms/step - loss: 1.5530 - error_rate: 0.3261 - val_loss: 1.6306 - val_error_rate: 0.3633 - lr: 0.1000
# new lr:1.00e-01
# Epoch 21/100
# 352/352 [==============================] - 40s 112ms/step - loss: 1.4674 - error_rate: 0.3162 - val_loss: 1.6989 - val_error_rate: 0.4007 - lr: 0.1000
# new lr:1.00e-01
# Epoch 22/100
# 352/352 [==============================] - 39s 111ms/step - loss: 1.3853 - error_rate: 0.3020 - val_loss: 1.8473 - val_error_rate: 0.4341 - lr: 0.1000
# new lr:1.00e-01
# Epoch 23/100
# 352/352 [==============================] - 38s 107ms/step - loss: 1.3316 - error_rate: 0.2971 - val_loss: 1.6658 - val_error_rate: 0.3959 - lr: 0.1000
# new lr:1.00e-01
# Epoch 24/100
# 352/352 [==============================] - 39s 110ms/step - loss: 1.2696 - error_rate: 0.2886 - val_loss: 1.7238 - val_error_rate: 0.3967 - lr: 0.1000
# new lr:1.00e-01
# Epoch 25/100
# 352/352 [==============================] - 53s 150ms/step - loss: 1.2315 - error_rate: 0.2871 - val_loss: 1.3654 - val_error_rate: 0.3392 - lr: 0.1000
# new lr:1.00e-01
# Epoch 26/100
# 352/352 [==============================] - 37s 106ms/step - loss: 1.1743 - error_rate: 0.2752 - val_loss: 1.8147 - val_error_rate: 0.5092 - lr: 0.1000
# new lr:1.00e-01
# Epoch 27/100
# 352/352 [==============================] - 39s 109ms/step - loss: 1.1434 - error_rate: 0.2722 - val_loss: 2.2787 - val_error_rate: 0.5201 - lr: 0.1000
# new lr:1.00e-01
# Epoch 28/100
# 352/352 [==============================] - 39s 112ms/step - loss: 1.1100 - error_rate: 0.2687 - val_loss: 2.7064 - val_error_rate: 0.5685 - lr: 0.1000
# new lr:1.00e-01
# Epoch 29/100
# 352/352 [==============================] - 39s 111ms/step - loss: 1.0760 - error_rate: 0.2632 - val_loss: 2.3358 - val_error_rate: 0.6039 - lr: 0.1000
# new lr:1.00e-01
# Epoch 30/100
# 352/352 [==============================] - 38s 107ms/step - loss: 1.0514 - error_rate: 0.2598 - val_loss: 1.4882 - val_error_rate: 0.3828 - lr: 0.1000
# new lr:1.00e-01
# Epoch 31/100
# 352/352 [==============================] - 38s 108ms/step - loss: 1.0278 - error_rate: 0.2549 - val_loss: 1.7824 - val_error_rate: 0.4546 - lr: 0.1000
# new lr:1.00e-01
# Epoch 32/100
# 352/352 [==============================] - 39s 112ms/step - loss: 1.0119 - error_rate: 0.2521 - val_loss: 1.3822 - val_error_rate: 0.3648 - lr: 0.1000
# new lr:1.00e-01
# Epoch 33/100
# 352/352 [==============================] - 55s 157ms/step - loss: 0.9820 - error_rate: 0.2458 - val_loss: 1.2865 - val_error_rate: 0.3555 - lr: 0.1000
# new lr:1.00e-01
# Epoch 34/100
# 352/352 [==============================] - 38s 108ms/step - loss: 0.9704 - error_rate: 0.2447 - val_loss: 2.0791 - val_error_rate: 0.4966 - lr: 0.1000
# new lr:1.00e-01
# Epoch 35/100
# 352/352 [==============================] - 37s 105ms/step - loss: 0.9641 - error_rate: 0.2434 - val_loss: 3.2472 - val_error_rate: 0.6501 - lr: 0.1000
# new lr:1.00e-01
# Epoch 36/100
# 352/352 [==============================] - 39s 109ms/step - loss: 0.9463 - error_rate: 0.2376 - val_loss: 1.5530 - val_error_rate: 0.4142 - lr: 0.1000
# new lr:1.00e-01
# Epoch 37/100
# 352/352 [==============================] - 53s 150ms/step - loss: 0.9304 - error_rate: 0.2351 - val_loss: 1.1379 - val_error_rate: 0.3049 - lr: 0.1000
# new lr:1.00e-01
# Epoch 38/100
# 352/352 [==============================] - 39s 112ms/step - loss: 0.9208 - error_rate: 0.2343 - val_loss: 1.5170 - val_error_rate: 0.4037 - lr: 0.1000
# new lr:1.00e-01
# Epoch 39/100
# 352/352 [==============================] - 37s 105ms/step - loss: 0.9116 - error_rate: 0.2329 - val_loss: 2.4873 - val_error_rate: 0.5756 - lr: 0.1000
# new lr:1.00e-01
# Epoch 40/100
# 352/352 [==============================] - 37s 104ms/step - loss: 0.9089 - error_rate: 0.2313 - val_loss: 1.1415 - val_error_rate: 0.3071 - lr: 0.1000
# new lr:1.00e-01
# Epoch 41/100
# 352/352 [==============================] - 38s 109ms/step - loss: 0.9038 - error_rate: 0.2287 - val_loss: 1.2257 - val_error_rate: 0.3414 - lr: 0.1000
# new lr:1.00e-01
# Epoch 42/100
# 352/352 [==============================] - 38s 108ms/step - loss: 0.8894 - error_rate: 0.2254 - val_loss: 1.9987 - val_error_rate: 0.5014 - lr: 0.1000
# new lr:1.00e-01
# Epoch 43/100
# 352/352 [==============================] - 36s 102ms/step - loss: 0.8738 - error_rate: 0.2186 - val_loss: 1.4022 - val_error_rate: 0.3660 - lr: 0.1000
# new lr:1.00e-01
# Epoch 44/100
# 352/352 [==============================] - 38s 107ms/step - loss: 0.8754 - error_rate: 0.2210 - val_loss: 1.3231 - val_error_rate: 0.3575 - lr: 0.1000
# new lr:1.00e-01
# Epoch 45/100
# 352/352 [==============================] - 37s 104ms/step - loss: 0.8775 - error_rate: 0.2248 - val_loss: 1.2806 - val_error_rate: 0.3579 - lr: 0.1000
# new lr:1.00e-01
# Epoch 46/100
# 352/352 [==============================] - 36s 103ms/step - loss: 0.8689 - error_rate: 0.2193 - val_loss: 1.4472 - val_error_rate: 0.3808 - lr: 0.1000
# new lr:1.00e-01
# Epoch 47/100
# 352/352 [==============================] - 38s 107ms/step - loss: 0.8680 - error_rate: 0.2206 - val_loss: 1.5448 - val_error_rate: 0.3881 - lr: 0.1000
# new lr:1.00e-01
# Epoch 48/100
# 352/352 [==============================] - 38s 107ms/step - loss: 0.8660 - error_rate: 0.2175 - val_loss: 1.1755 - val_error_rate: 0.3223 - lr: 0.1000
# new lr:1.00e-01
# Epoch 49/100
# 352/352 [==============================] - 36s 102ms/step - loss: 0.8562 - error_rate: 0.2150 - val_loss: 1.5812 - val_error_rate: 0.4160 - lr: 0.1000
# new lr:1.00e-01
# Epoch 50/100
# 352/352 [==============================] - 38s 107ms/step - loss: 0.8534 - error_rate: 0.2146 - val_loss: 1.2549 - val_error_rate: 0.3310 - lr: 0.1000
# new lr:1.00e-01
# Epoch 51/100
# 352/352 [==============================] - 37s 106ms/step - loss: 0.8522 - error_rate: 0.2109 - val_loss: 2.5813 - val_error_rate: 0.5412 - lr: 0.1000
# new lr:1.00e-02
# Epoch 52/100
# 352/352 [==============================] - 51s 144ms/step - loss: 0.7334 - error_rate: 0.1724 - val_loss: 0.7286 - val_error_rate: 0.1754 - lr: 0.0100
# new lr:1.00e-02
# Epoch 53/100
# 352/352 [==============================] - 52s 148ms/step - loss: 0.6676 - error_rate: 0.1507 - val_loss: 0.7234 - val_error_rate: 0.1710 - lr: 0.0100
# new lr:1.00e-02
# Epoch 54/100
# 352/352 [==============================] - 52s 148ms/step - loss: 0.6462 - error_rate: 0.1444 - val_loss: 0.7004 - val_error_rate: 0.1636 - lr: 0.0100
# new lr:1.00e-02
# Epoch 55/100
# 352/352 [==============================] - 51s 145ms/step - loss: 0.6312 - error_rate: 0.1413 - val_loss: 0.7000 - val_error_rate: 0.1638 - lr: 0.0100
# new lr:1.00e-02
# Epoch 56/100
# 352/352 [==============================] - 39s 111ms/step - loss: 0.6191 - error_rate: 0.1362 - val_loss: 0.7314 - val_error_rate: 0.1789 - lr: 0.0100
# new lr:1.00e-02
# Epoch 57/100
# 352/352 [==============================] - 39s 109ms/step - loss: 0.6116 - error_rate: 0.1349 - val_loss: 0.7119 - val_error_rate: 0.1762 - lr: 0.0100
# new lr:1.00e-02
# Epoch 58/100
# 352/352 [==============================] - 53s 150ms/step - loss: 0.6023 - error_rate: 0.1326 - val_loss: 0.6929 - val_error_rate: 0.1612 - lr: 0.0100
# new lr:1.00e-02
# Epoch 59/100
# 352/352 [==============================] - 54s 153ms/step - loss: 0.5935 - error_rate: 0.1305 - val_loss: 0.6833 - val_error_rate: 0.1610 - lr: 0.0100
# new lr:1.00e-02
# Epoch 60/100
# 352/352 [==============================] - 39s 110ms/step - loss: 0.5818 - error_rate: 0.1286 - val_loss: 0.7451 - val_error_rate: 0.1781 - lr: 0.0100
# new lr:1.00e-02
# Epoch 61/100
# 352/352 [==============================] - 37s 104ms/step - loss: 0.5789 - error_rate: 0.1288 - val_loss: 0.7042 - val_error_rate: 0.1754 - lr: 0.0100
# new lr:1.00e-02
# Epoch 62/100
# 352/352 [==============================] - 54s 152ms/step - loss: 0.5731 - error_rate: 0.1273 - val_loss: 0.6685 - val_error_rate: 0.1602 - lr: 0.0100
# new lr:1.00e-02
# Epoch 63/100
# 352/352 [==============================] - 39s 111ms/step - loss: 0.5616 - error_rate: 0.1232 - val_loss: 0.7089 - val_error_rate: 0.1728 - lr: 0.0100
# new lr:1.00e-02
# Epoch 64/100
# 352/352 [==============================] - 38s 107ms/step - loss: 0.5567 - error_rate: 0.1227 - val_loss: 0.7043 - val_error_rate: 0.1710 - lr: 0.0100
# new lr:1.00e-02
# Epoch 65/100
# 352/352 [==============================] - 37s 106ms/step - loss: 0.5533 - error_rate: 0.1230 - val_loss: 0.6781 - val_error_rate: 0.1632 - lr: 0.0100
# new lr:1.00e-02
# Epoch 66/100
# 352/352 [==============================] - 38s 107ms/step - loss: 0.5491 - error_rate: 0.1230 - val_loss: 0.7106 - val_error_rate: 0.1779 - lr: 0.0100
# new lr:1.00e-02
# Epoch 67/100
# 352/352 [==============================] - 37s 104ms/step - loss: 0.5428 - error_rate: 0.1199 - val_loss: 0.6804 - val_error_rate: 0.1652 - lr: 0.0100
# new lr:1.00e-02
# Epoch 68/100
# 352/352 [==============================] - 38s 109ms/step - loss: 0.5408 - error_rate: 0.1201 - val_loss: 0.6870 - val_error_rate: 0.1676 - lr: 0.0100
# new lr:1.00e-02
# Epoch 69/100
# 352/352 [==============================] - 38s 108ms/step - loss: 0.5336 - error_rate: 0.1185 - val_loss: 0.6944 - val_error_rate: 0.1682 - lr: 0.0100
# new lr:1.00e-02
# Epoch 70/100
# 352/352 [==============================] - 37s 105ms/step - loss: 0.5276 - error_rate: 0.1157 - val_loss: 0.8637 - val_error_rate: 0.2178 - lr: 0.0100
# new lr:1.00e-02
# Epoch 71/100
# 352/352 [==============================] - 38s 109ms/step - loss: 0.5227 - error_rate: 0.1163 - val_loss: 0.7347 - val_error_rate: 0.1825 - lr: 0.0100
# new lr:1.00e-02
# Epoch 72/100
# 352/352 [==============================] - 53s 149ms/step - loss: 0.5171 - error_rate: 0.1148 - val_loss: 0.6666 - val_error_rate: 0.1674 - lr: 0.0100
# new lr:1.00e-02
# Epoch 73/100
# 352/352 [==============================] - 36s 103ms/step - loss: 0.5144 - error_rate: 0.1156 - val_loss: 0.7341 - val_error_rate: 0.1909 - lr: 0.0100
# new lr:1.00e-02
# Epoch 74/100
# 352/352 [==============================] - 52s 149ms/step - loss: 0.5093 - error_rate: 0.1132 - val_loss: 0.6617 - val_error_rate: 0.1608 - lr: 0.0100
# new lr:1.00e-02
# Epoch 75/100
# 352/352 [==============================] - 39s 111ms/step - loss: 0.5041 - error_rate: 0.1132 - val_loss: 0.6667 - val_error_rate: 0.1722 - lr: 0.0100
# new lr:1.00e-02
# Epoch 76/100
# 352/352 [==============================] - 51s 145ms/step - loss: 0.5034 - error_rate: 0.1116 - val_loss: 0.6575 - val_error_rate: 0.1600 - lr: 0.0100
# new lr:1.00e-03
# Epoch 77/100
# 352/352 [==============================] - 57s 163ms/step - loss: 0.4813 - error_rate: 0.1066 - val_loss: 0.6076 - val_error_rate: 0.1479 - lr: 0.0010
# new lr:1.00e-03
# Epoch 78/100
# 352/352 [==============================] - 38s 109ms/step - loss: 0.4649 - error_rate: 0.1011 - val_loss: 0.6082 - val_error_rate: 0.1465 - lr: 0.0010
# new lr:1.00e-03
# Epoch 79/100
# 352/352 [==============================] - 53s 151ms/step - loss: 0.4594 - error_rate: 0.0983 - val_loss: 0.6073 - val_error_rate: 0.1437 - lr: 0.0010
# new lr:1.00e-03
# Epoch 80/100
# 352/352 [==============================] - 54s 154ms/step - loss: 0.4594 - error_rate: 0.0972 - val_loss: 0.6056 - val_error_rate: 0.1437 - lr: 0.0010
# new lr:1.00e-03
# Epoch 81/100
# 352/352 [==============================] - 40s 113ms/step - loss: 0.4528 - error_rate: 0.0959 - val_loss: 0.6119 - val_error_rate: 0.1473 - lr: 0.0010
# new lr:1.00e-03
# Epoch 82/100
# 352/352 [==============================] - 37s 106ms/step - loss: 0.4542 - error_rate: 0.0962 - val_loss: 0.6152 - val_error_rate: 0.1481 - lr: 0.0010
# new lr:1.00e-03
# Epoch 83/100
# 352/352 [==============================] - 53s 150ms/step - loss: 0.4530 - error_rate: 0.0960 - val_loss: 0.6042 - val_error_rate: 0.1419 - lr: 0.0010
# new lr:1.00e-03
# Epoch 84/100
# 352/352 [==============================] - 39s 112ms/step - loss: 0.4522 - error_rate: 0.0963 - val_loss: 0.6090 - val_error_rate: 0.1449 - lr: 0.0010
# new lr:1.00e-03
# Epoch 85/100
# 352/352 [==============================] - 39s 111ms/step - loss: 0.4519 - error_rate: 0.0953 - val_loss: 0.6066 - val_error_rate: 0.1423 - lr: 0.0010
# new lr:1.00e-03
# Epoch 86/100
# 352/352 [==============================] - 39s 112ms/step - loss: 0.4486 - error_rate: 0.0954 - val_loss: 0.6067 - val_error_rate: 0.1455 - lr: 0.0010
# new lr:1.00e-03
# Epoch 87/100
# 352/352 [==============================] - 38s 107ms/step - loss: 0.4447 - error_rate: 0.0936 - val_loss: 0.6073 - val_error_rate: 0.1425 - lr: 0.0010
# new lr:1.00e-03
# Epoch 88/100
# 352/352 [==============================] - 41s 116ms/step - loss: 0.4464 - error_rate: 0.0960 - val_loss: 0.6084 - val_error_rate: 0.1457 - lr: 0.0010
# new lr:1.00e-03
# Epoch 89/100
# 352/352 [==============================] - 39s 112ms/step - loss: 0.4420 - error_rate: 0.0933 - val_loss: 0.6090 - val_error_rate: 0.1419 - lr: 0.0010
# new lr:1.00e-03
# Epoch 90/100
# 352/352 [==============================] - 38s 107ms/step - loss: 0.4440 - error_rate: 0.0946 - val_loss: 0.6063 - val_error_rate: 0.1415 - lr: 0.0010
# new lr:1.00e-03
# Epoch 91/100
# 352/352 [==============================] - 39s 110ms/step - loss: 0.4400 - error_rate: 0.0916 - val_loss: 0.6117 - val_error_rate: 0.1445 - lr: 0.0010
# new lr:1.00e-03
# Epoch 92/100
# 352/352 [==============================] - 39s 112ms/step - loss: 0.4450 - error_rate: 0.0959 - val_loss: 0.6085 - val_error_rate: 0.1455 - lr: 0.0010
# new lr:1.00e-03
# Epoch 93/100
# 352/352 [==============================] - 39s 109ms/step - loss: 0.4408 - error_rate: 0.0938 - val_loss: 0.6104 - val_error_rate: 0.1447 - lr: 0.0010
# new lr:1.00e-03
# Epoch 94/100
# 352/352 [==============================] - 37s 106ms/step - loss: 0.4394 - error_rate: 0.0915 - val_loss: 0.6108 - val_error_rate: 0.1473 - lr: 0.0010
# new lr:1.00e-03
# Epoch 95/100
# 352/352 [==============================] - 39s 111ms/step - loss: 0.4403 - error_rate: 0.0920 - val_loss: 0.6062 - val_error_rate: 0.1417 - lr: 0.0010
# new lr:1.00e-03
# Epoch 96/100
# 352/352 [==============================] - 38s 108ms/step - loss: 0.4405 - error_rate: 0.0928 - val_loss: 0.6116 - val_error_rate: 0.1447 - lr: 0.0010
# new lr:1.00e-03
# Epoch 97/100
# 352/352 [==============================] - 37s 105ms/step - loss: 0.4320 - error_rate: 0.0911 - val_loss: 0.6110 - val_error_rate: 0.1453 - lr: 0.0010
# new lr:1.00e-03
# Epoch 98/100
# 352/352 [==============================] - 37s 104ms/step - loss: 0.4379 - error_rate: 0.0922 - val_loss: 0.6106 - val_error_rate: 0.1455 - lr: 0.0010
# new lr:1.00e-03
# Epoch 99/100
# 352/352 [==============================] - 38s 109ms/step - loss: 0.4406 - error_rate: 0.0933 - val_loss: 0.6119 - val_error_rate: 0.1467 - lr: 0.0010
# new lr:1.00e-03
# Epoch 100/100
# 352/352 [==============================] - 38s 108ms/step - loss: 0.4362 - error_rate: 0.0929 - val_loss: 0.6152 - val_error_rate: 0.1481 - lr: 0.0010

# %%
reduce_lr_2 = LearningRateScheduler(lr_scheduler)
mc2 = keras.callbacks.ModelCheckpoint(filepath="resnet44_cifar10.tf",
                                      monitor='val_loss',
                                      mode='min',
                                      verbose=0,
                                      save_best_only=True)
solver_res_44 = CIFAR10Solver(resnet44, data)
history_res_44 = solver_res_44.train(epochs=EPOCHS, batch_size=128, data_augmentation=True,
                                     callbacks=[reduce_lr_2, mc2])
# Out:
# train with data augmentation
# new lr:1.00e-01
# Epoch 1/100
# <ipython-input-7-fec8c7b98f6b>:28: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = self.model.fit_generator(generator=train_gen,
# 352/352 [==============================] - 67s 155ms/step - loss: 2.2900 - error_rate: 0.7322 - val_loss: 2.6241 - val_error_rate: 0.7456 - lr: 0.1000
# new lr:1.00e-01
# Epoch 2/100
# 352/352 [==============================] - 54s 154ms/step - loss: 1.8254 - error_rate: 0.5906 - val_loss: 1.8066 - val_error_rate: 0.5750 - lr: 0.1000
# new lr:1.00e-01
# Epoch 3/100
# 352/352 [==============================] - 54s 152ms/step - loss: 1.5808 - error_rate: 0.4981 - val_loss: 1.7294 - val_error_rate: 0.5147 - lr: 0.1000
# new lr:1.00e-01
# Epoch 4/100
# 352/352 [==============================] - 55s 155ms/step - loss: 1.3533 - error_rate: 0.4108 - val_loss: 1.6528 - val_error_rate: 0.4825 - lr: 0.1000
# new lr:1.00e-01
# Epoch 5/100
# 352/352 [==============================] - 54s 155ms/step - loss: 1.1750 - error_rate: 0.3444 - val_loss: 1.2770 - val_error_rate: 0.3909 - lr: 0.1000
# new lr:1.00e-01
# Epoch 6/100
# 352/352 [==============================] - 39s 110ms/step - loss: 1.0601 - error_rate: 0.3042 - val_loss: 1.3343 - val_error_rate: 0.3557 - lr: 0.1000
# new lr:1.00e-01
# Epoch 7/100
# 352/352 [==============================] - 54s 154ms/step - loss: 0.9846 - error_rate: 0.2756 - val_loss: 0.9963 - val_error_rate: 0.2809 - lr: 0.1000
# new lr:1.00e-01
# Epoch 8/100
# 352/352 [==============================] - 38s 107ms/step - loss: 0.9025 - error_rate: 0.2451 - val_loss: 1.0259 - val_error_rate: 0.2850 - lr: 0.1000
# new lr:1.00e-01
# Epoch 9/100
# 352/352 [==============================] - 55s 156ms/step - loss: 0.8450 - error_rate: 0.2266 - val_loss: 0.8913 - val_error_rate: 0.2402 - lr: 0.1000
# new lr:1.00e-01
# Epoch 10/100
# 352/352 [==============================] - 39s 110ms/step - loss: 0.7959 - error_rate: 0.2060 - val_loss: 1.0091 - val_error_rate: 0.2761 - lr: 0.1000
# new lr:1.00e-01
# Epoch 11/100
# 352/352 [==============================] - 39s 111ms/step - loss: 0.7586 - error_rate: 0.1966 - val_loss: 0.9841 - val_error_rate: 0.2609 - lr: 0.1000
# new lr:1.00e-01
# Epoch 12/100
# 352/352 [==============================] - 38s 109ms/step - loss: 0.7191 - error_rate: 0.1813 - val_loss: 1.0048 - val_error_rate: 0.2617 - lr: 0.1000
# new lr:1.00e-01
# Epoch 13/100
# 352/352 [==============================] - 54s 153ms/step - loss: 0.6994 - error_rate: 0.1742 - val_loss: 0.8431 - val_error_rate: 0.2287 - lr: 0.1000
# new lr:1.00e-01
# Epoch 14/100
# 352/352 [==============================] - 37s 106ms/step - loss: 0.6734 - error_rate: 0.1653 - val_loss: 0.8478 - val_error_rate: 0.2229 - lr: 0.1000
# new lr:1.00e-01
# Epoch 15/100
# 352/352 [==============================] - 54s 154ms/step - loss: 0.6519 - error_rate: 0.1566 - val_loss: 0.7823 - val_error_rate: 0.2022 - lr: 0.1000
# new lr:1.00e-01
# Epoch 16/100
# 352/352 [==============================] - 39s 111ms/step - loss: 0.6347 - error_rate: 0.1511 - val_loss: 1.0173 - val_error_rate: 0.2574 - lr: 0.1000
# new lr:1.00e-01
# Epoch 17/100
# 352/352 [==============================] - 38s 108ms/step - loss: 0.6246 - error_rate: 0.1469 - val_loss: 0.9512 - val_error_rate: 0.2446 - lr: 0.1000
# new lr:1.00e-01
# Epoch 18/100
# 352/352 [==============================] - 55s 156ms/step - loss: 0.6079 - error_rate: 0.1406 - val_loss: 0.7739 - val_error_rate: 0.1901 - lr: 0.1000
# new lr:1.00e-01
# Epoch 19/100
# 352/352 [==============================] - 38s 106ms/step - loss: 0.5978 - error_rate: 0.1358 - val_loss: 0.8351 - val_error_rate: 0.2054 - lr: 0.1000
# new lr:1.00e-01
# Epoch 20/100
# 352/352 [==============================] - 38s 107ms/step - loss: 0.5837 - error_rate: 0.1306 - val_loss: 0.7936 - val_error_rate: 0.1929 - lr: 0.1000
# new lr:1.00e-01
# Epoch 21/100
# 352/352 [==============================] - 39s 112ms/step - loss: 0.5795 - error_rate: 0.1288 - val_loss: 0.7752 - val_error_rate: 0.1921 - lr: 0.1000
# new lr:1.00e-01
# Epoch 22/100
# 352/352 [==============================] - 38s 107ms/step - loss: 0.5721 - error_rate: 0.1269 - val_loss: 0.7889 - val_error_rate: 0.1957 - lr: 0.1000
# new lr:1.00e-01
# Epoch 23/100
# 352/352 [==============================] - 40s 114ms/step - loss: 0.5643 - error_rate: 0.1211 - val_loss: 1.1071 - val_error_rate: 0.2625 - lr: 0.1000
# new lr:1.00e-01
# Epoch 24/100
# 352/352 [==============================] - 39s 112ms/step - loss: 0.5554 - error_rate: 0.1187 - val_loss: 1.3031 - val_error_rate: 0.3053 - lr: 0.1000
# new lr:1.00e-01
# Epoch 25/100
# 352/352 [==============================] - 55s 156ms/step - loss: 0.5537 - error_rate: 0.1181 - val_loss: 0.7035 - val_error_rate: 0.1626 - lr: 0.1000
# new lr:1.00e-01
# Epoch 26/100
# 352/352 [==============================] - 37s 105ms/step - loss: 0.5402 - error_rate: 0.1131 - val_loss: 0.9260 - val_error_rate: 0.2144 - lr: 0.1000
# new lr:1.00e-01
# Epoch 27/100
# 352/352 [==============================] - 39s 110ms/step - loss: 0.5442 - error_rate: 0.1125 - val_loss: 0.7097 - val_error_rate: 0.1622 - lr: 0.1000
# new lr:1.00e-01
# Epoch 28/100
# 352/352 [==============================] - 39s 110ms/step - loss: 0.5358 - error_rate: 0.1098 - val_loss: 0.7258 - val_error_rate: 0.1602 - lr: 0.1000
# new lr:1.00e-01
# Epoch 29/100
# 352/352 [==============================] - 38s 108ms/step - loss: 0.5316 - error_rate: 0.1088 - val_loss: 0.7904 - val_error_rate: 0.1855 - lr: 0.1000
# new lr:1.00e-01
# Epoch 30/100
# 352/352 [==============================] - 38s 106ms/step - loss: 0.5261 - error_rate: 0.1056 - val_loss: 0.7946 - val_error_rate: 0.1907 - lr: 0.1000
# new lr:1.00e-01
# Epoch 31/100
# 352/352 [==============================] - 39s 110ms/step - loss: 0.5242 - error_rate: 0.1048 - val_loss: 0.7075 - val_error_rate: 0.1654 - lr: 0.1000
# new lr:1.00e-01
# Epoch 32/100
# 352/352 [==============================] - 37s 106ms/step - loss: 0.5222 - error_rate: 0.1031 - val_loss: 0.7461 - val_error_rate: 0.1760 - lr: 0.1000
# new lr:1.00e-01
# Epoch 33/100
# 352/352 [==============================] - 37s 106ms/step - loss: 0.5177 - error_rate: 0.1012 - val_loss: 0.9095 - val_error_rate: 0.2116 - lr: 0.1000
# new lr:1.00e-01
# Epoch 34/100
# 352/352 [==============================] - 38s 109ms/step - loss: 0.5211 - error_rate: 0.1019 - val_loss: 0.7890 - val_error_rate: 0.1662 - lr: 0.1000
# new lr:1.00e-01
# Epoch 35/100
# 352/352 [==============================] - 40s 112ms/step - loss: 0.5097 - error_rate: 0.0971 - val_loss: 0.8954 - val_error_rate: 0.2116 - lr: 0.1000
# new lr:1.00e-01
# Epoch 36/100
# 352/352 [==============================] - 39s 110ms/step - loss: 0.5105 - error_rate: 0.0980 - val_loss: 0.7465 - val_error_rate: 0.1646 - lr: 0.1000
# new lr:1.00e-01
# Epoch 37/100
# 352/352 [==============================] - 53s 152ms/step - loss: 0.5090 - error_rate: 0.0951 - val_loss: 0.6756 - val_error_rate: 0.1483 - lr: 0.1000
# new lr:1.00e-01
# Epoch 38/100
# 352/352 [==============================] - 39s 111ms/step - loss: 0.5055 - error_rate: 0.0951 - val_loss: 0.7549 - val_error_rate: 0.1809 - lr: 0.1000
# new lr:1.00e-01
# Epoch 39/100
# 352/352 [==============================] - 37s 106ms/step - loss: 0.5014 - error_rate: 0.0945 - val_loss: 0.7134 - val_error_rate: 0.1561 - lr: 0.1000
# new lr:1.00e-01
# Epoch 40/100
# 352/352 [==============================] - 39s 111ms/step - loss: 0.5052 - error_rate: 0.0949 - val_loss: 0.8560 - val_error_rate: 0.1893 - lr: 0.1000
# new lr:1.00e-01
# Epoch 41/100
# 352/352 [==============================] - 39s 111ms/step - loss: 0.4931 - error_rate: 0.0899 - val_loss: 0.7770 - val_error_rate: 0.1734 - lr: 0.1000
# new lr:1.00e-01
# Epoch 42/100
# 352/352 [==============================] - 38s 107ms/step - loss: 0.5032 - error_rate: 0.0931 - val_loss: 0.8493 - val_error_rate: 0.1847 - lr: 0.1000
# new lr:1.00e-01
# Epoch 43/100
# 352/352 [==============================] - 39s 111ms/step - loss: 0.4961 - error_rate: 0.0889 - val_loss: 0.8582 - val_error_rate: 0.1837 - lr: 0.1000
# new lr:1.00e-01
# Epoch 44/100
# 352/352 [==============================] - 39s 112ms/step - loss: 0.4925 - error_rate: 0.0902 - val_loss: 0.7780 - val_error_rate: 0.1762 - lr: 0.1000
# new lr:1.00e-01
# Epoch 45/100
# 352/352 [==============================] - 38s 109ms/step - loss: 0.4937 - error_rate: 0.0891 - val_loss: 0.8087 - val_error_rate: 0.1773 - lr: 0.1000
# new lr:1.00e-01
# Epoch 46/100
# 352/352 [==============================] - 38s 108ms/step - loss: 0.4926 - error_rate: 0.0892 - val_loss: 0.8061 - val_error_rate: 0.1807 - lr: 0.1000
# new lr:1.00e-01
# Epoch 47/100
# 352/352 [==============================] - 39s 110ms/step - loss: 0.4863 - error_rate: 0.0845 - val_loss: 0.7103 - val_error_rate: 0.1509 - lr: 0.1000
# new lr:1.00e-01
# Epoch 48/100
# 352/352 [==============================] - 39s 111ms/step - loss: 0.4896 - error_rate: 0.0862 - val_loss: 0.9327 - val_error_rate: 0.2094 - lr: 0.1000
# new lr:1.00e-01
# Epoch 49/100
# 352/352 [==============================] - 39s 110ms/step - loss: 0.4854 - error_rate: 0.0841 - val_loss: 0.8698 - val_error_rate: 0.1853 - lr: 0.1000
# new lr:1.00e-01
# Epoch 50/100
# 352/352 [==============================] - 38s 109ms/step - loss: 0.4835 - error_rate: 0.0853 - val_loss: 0.7435 - val_error_rate: 0.1668 - lr: 0.1000
# new lr:1.00e-01
# Epoch 51/100
# 352/352 [==============================] - 38s 107ms/step - loss: 0.4839 - error_rate: 0.0843 - val_loss: 0.7246 - val_error_rate: 0.1541 - lr: 0.1000
# new lr:1.00e-02
# Epoch 52/100
# 352/352 [==============================] - 55s 157ms/step - loss: 0.4086 - error_rate: 0.0571 - val_loss: 0.5210 - val_error_rate: 0.0886 - lr: 0.0100
# new lr:1.00e-02
# Epoch 53/100
# 352/352 [==============================] - 55s 157ms/step - loss: 0.3570 - error_rate: 0.0397 - val_loss: 0.5063 - val_error_rate: 0.0816 - lr: 0.0100
# new lr:1.00e-02
# Epoch 54/100
# 352/352 [==============================] - 56s 158ms/step - loss: 0.3393 - error_rate: 0.0351 - val_loss: 0.5046 - val_error_rate: 0.0832 - lr: 0.0100
# new lr:1.00e-02
# Epoch 55/100
# 352/352 [==============================] - 55s 157ms/step - loss: 0.3247 - error_rate: 0.0309 - val_loss: 0.5004 - val_error_rate: 0.0824 - lr: 0.0100
# new lr:1.00e-02
# Epoch 56/100
# 352/352 [==============================] - 55s 157ms/step - loss: 0.3157 - error_rate: 0.0286 - val_loss: 0.4974 - val_error_rate: 0.0806 - lr: 0.0100
# new lr:1.00e-02
# Epoch 57/100
# 352/352 [==============================] - 39s 111ms/step - loss: 0.3058 - error_rate: 0.0266 - val_loss: 0.5155 - val_error_rate: 0.0854 - lr: 0.0100
# new lr:1.00e-02
# Epoch 58/100
# 352/352 [==============================] - 38s 108ms/step - loss: 0.2995 - error_rate: 0.0245 - val_loss: 0.5117 - val_error_rate: 0.0846 - lr: 0.0100
# new lr:1.00e-02
# Epoch 59/100
# 352/352 [==============================] - 38s 108ms/step - loss: 0.2894 - error_rate: 0.0227 - val_loss: 0.5120 - val_error_rate: 0.0834 - lr: 0.0100
# new lr:1.00e-02
# Epoch 60/100
# 352/352 [==============================] - 39s 112ms/step - loss: 0.2826 - error_rate: 0.0206 - val_loss: 0.5236 - val_error_rate: 0.0852 - lr: 0.0100
# new lr:1.00e-02
# Epoch 61/100
# 352/352 [==============================] - 39s 112ms/step - loss: 0.2774 - error_rate: 0.0205 - val_loss: 0.5120 - val_error_rate: 0.0812 - lr: 0.0100
# new lr:1.00e-02
# Epoch 62/100
# 352/352 [==============================] - 39s 111ms/step - loss: 0.2715 - error_rate: 0.0198 - val_loss: 0.5100 - val_error_rate: 0.0826 - lr: 0.0100
# new lr:1.00e-02
# Epoch 63/100
# 352/352 [==============================] - 38s 107ms/step - loss: 0.2634 - error_rate: 0.0169 - val_loss: 0.5125 - val_error_rate: 0.0844 - lr: 0.0100
# new lr:1.00e-02
# Epoch 64/100
# 352/352 [==============================] - 39s 111ms/step - loss: 0.2592 - error_rate: 0.0168 - val_loss: 0.5296 - val_error_rate: 0.0842 - lr: 0.0100
# new lr:1.00e-02
# Epoch 65/100
# 352/352 [==============================] - 40s 114ms/step - loss: 0.2557 - error_rate: 0.0164 - val_loss: 0.5102 - val_error_rate: 0.0808 - lr: 0.0100
# new lr:1.00e-02
# Epoch 66/100
# 352/352 [==============================] - 38s 107ms/step - loss: 0.2491 - error_rate: 0.0155 - val_loss: 0.5185 - val_error_rate: 0.0820 - lr: 0.0100
# new lr:1.00e-02
# Epoch 67/100
# 352/352 [==============================] - 39s 109ms/step - loss: 0.2451 - error_rate: 0.0146 - val_loss: 0.5167 - val_error_rate: 0.0816 - lr: 0.0100
# new lr:1.00e-02
# Epoch 68/100
# 352/352 [==============================] - 39s 111ms/step - loss: 0.2385 - error_rate: 0.0129 - val_loss: 0.5340 - val_error_rate: 0.0836 - lr: 0.0100
# new lr:1.00e-02
# Epoch 69/100
# 352/352 [==============================] - 40s 113ms/step - loss: 0.2341 - error_rate: 0.0127 - val_loss: 0.5430 - val_error_rate: 0.0820 - lr: 0.0100
# new lr:1.00e-02
# Epoch 70/100
# 352/352 [==============================] - 38s 107ms/step - loss: 0.2318 - error_rate: 0.0124 - val_loss: 0.5374 - val_error_rate: 0.0824 - lr: 0.0100
# new lr:1.00e-02
# Epoch 71/100
# 352/352 [==============================] - 40s 112ms/step - loss: 0.2251 - error_rate: 0.0114 - val_loss: 0.5407 - val_error_rate: 0.0848 - lr: 0.0100
# new lr:1.00e-02
# Epoch 72/100
# 352/352 [==============================] - 39s 110ms/step - loss: 0.2221 - error_rate: 0.0115 - val_loss: 0.5691 - val_error_rate: 0.0884 - lr: 0.0100
# new lr:1.00e-02
# Epoch 73/100
# 352/352 [==============================] - 38s 109ms/step - loss: 0.2210 - error_rate: 0.0113 - val_loss: 0.5585 - val_error_rate: 0.0894 - lr: 0.0100
# new lr:1.00e-02
# Epoch 74/100
# 352/352 [==============================] - 37s 105ms/step - loss: 0.2173 - error_rate: 0.0112 - val_loss: 0.5315 - val_error_rate: 0.0834 - lr: 0.0100
# new lr:1.00e-02
# Epoch 75/100
# 352/352 [==============================] - 39s 111ms/step - loss: 0.2132 - error_rate: 0.0107 - val_loss: 0.5354 - val_error_rate: 0.0850 - lr: 0.0100
# new lr:1.00e-02
# Epoch 76/100
# 352/352 [==============================] - 38s 109ms/step - loss: 0.2098 - error_rate: 0.0101 - val_loss: 0.5335 - val_error_rate: 0.0840 - lr: 0.0100
# new lr:1.00e-03
# Epoch 77/100
# 352/352 [==============================] - 37s 105ms/step - loss: 0.2053 - error_rate: 0.0085 - val_loss: 0.5217 - val_error_rate: 0.0834 - lr: 0.0010
# new lr:1.00e-03
# Epoch 78/100
# 352/352 [==============================] - 37s 104ms/step - loss: 0.2006 - error_rate: 0.0065 - val_loss: 0.5237 - val_error_rate: 0.0822 - lr: 0.0010
# new lr:1.00e-03
# Epoch 79/100
# 352/352 [==============================] - 38s 108ms/step - loss: 0.1999 - error_rate: 0.0073 - val_loss: 0.5218 - val_error_rate: 0.0818 - lr: 0.0010
# new lr:1.00e-03
# Epoch 80/100
# 352/352 [==============================] - 38s 109ms/step - loss: 0.1984 - error_rate: 0.0061 - val_loss: 0.5208 - val_error_rate: 0.0824 - lr: 0.0010
# new lr:1.00e-03
# Epoch 81/100
# 352/352 [==============================] - 37s 104ms/step - loss: 0.1988 - error_rate: 0.0063 - val_loss: 0.5218 - val_error_rate: 0.0814 - lr: 0.0010
# new lr:1.00e-03
# Epoch 82/100
# 352/352 [==============================] - 37s 105ms/step - loss: 0.1968 - error_rate: 0.0056 - val_loss: 0.5228 - val_error_rate: 0.0830 - lr: 0.0010
# new lr:1.00e-03
# Epoch 83/100
# 352/352 [==============================] - 37s 105ms/step - loss: 0.1958 - error_rate: 0.0055 - val_loss: 0.5236 - val_error_rate: 0.0824 - lr: 0.0010
# new lr:1.00e-03
# Epoch 84/100
# 352/352 [==============================] - 38s 108ms/step - loss: 0.1960 - error_rate: 0.0061 - val_loss: 0.5262 - val_error_rate: 0.0834 - lr: 0.0010
# new lr:1.00e-03
# Epoch 85/100
# 352/352 [==============================] - 38s 109ms/step - loss: 0.1951 - error_rate: 0.0055 - val_loss: 0.5281 - val_error_rate: 0.0832 - lr: 0.0010
# new lr:1.00e-03
# Epoch 86/100
# 352/352 [==============================] - 36s 103ms/step - loss: 0.1961 - error_rate: 0.0063 - val_loss: 0.5277 - val_error_rate: 0.0822 - lr: 0.0010
# new lr:1.00e-03
# Epoch 87/100
# 352/352 [==============================] - 38s 109ms/step - loss: 0.1939 - error_rate: 0.0052 - val_loss: 0.5285 - val_error_rate: 0.0830 - lr: 0.0010
# new lr:1.00e-03
# Epoch 88/100
# 352/352 [==============================] - 38s 109ms/step - loss: 0.1939 - error_rate: 0.0056 - val_loss: 0.5278 - val_error_rate: 0.0832 - lr: 0.0010
# new lr:1.00e-03
# Epoch 89/100
# 352/352 [==============================] - 37s 106ms/step - loss: 0.1932 - error_rate: 0.0051 - val_loss: 0.5261 - val_error_rate: 0.0832 - lr: 0.0010
# new lr:1.00e-03
# Epoch 90/100
# 352/352 [==============================] - 37s 104ms/step - loss: 0.1920 - error_rate: 0.0047 - val_loss: 0.5304 - val_error_rate: 0.0826 - lr: 0.0010
# new lr:1.00e-03
# Epoch 91/100
# 352/352 [==============================] - 38s 107ms/step - loss: 0.1916 - error_rate: 0.0045 - val_loss: 0.5295 - val_error_rate: 0.0826 - lr: 0.0010
# new lr:1.00e-03
# Epoch 92/100
# 352/352 [==============================] - 38s 109ms/step - loss: 0.1916 - error_rate: 0.0045 - val_loss: 0.5297 - val_error_rate: 0.0822 - lr: 0.0010
# new lr:1.00e-03
# Epoch 93/100
# 352/352 [==============================] - 36s 103ms/step - loss: 0.1903 - error_rate: 0.0044 - val_loss: 0.5291 - val_error_rate: 0.0828 - lr: 0.0010
# new lr:1.00e-03
# Epoch 94/100
# 352/352 [==============================] - 38s 108ms/step - loss: 0.1904 - error_rate: 0.0048 - val_loss: 0.5273 - val_error_rate: 0.0818 - lr: 0.0010
# new lr:1.00e-03
# Epoch 95/100
# 352/352 [==============================] - 39s 111ms/step - loss: 0.1889 - error_rate: 0.0043 - val_loss: 0.5309 - val_error_rate: 0.0828 - lr: 0.0010
# new lr:1.00e-03
# Epoch 96/100
# 352/352 [==============================] - 38s 109ms/step - loss: 0.1900 - error_rate: 0.0046 - val_loss: 0.5329 - val_error_rate: 0.0830 - lr: 0.0010
# new lr:1.00e-03
# Epoch 97/100
# 352/352 [==============================] - 37s 105ms/step - loss: 0.1892 - error_rate: 0.0043 - val_loss: 0.5318 - val_error_rate: 0.0830 - lr: 0.0010
# new lr:1.00e-03
# Epoch 98/100
# 352/352 [==============================] - 38s 108ms/step - loss: 0.1901 - error_rate: 0.0051 - val_loss: 0.5312 - val_error_rate: 0.0818 - lr: 0.0010
# new lr:1.00e-03
# Epoch 99/100
# 352/352 [==============================] - 38s 108ms/step - loss: 0.1894 - error_rate: 0.0048 - val_loss: 0.5328 - val_error_rate: 0.0820 - lr: 0.0010
# new lr:1.00e-03
# Epoch 100/100
# 352/352 [==============================] - 38s 107ms/step - loss: 0.1886 - error_rate: 0.0044 - val_loss: 0.5298 - val_error_rate: 0.0808 - lr: 0.0010

# %%
plt.figure(figsize=(10,8))
plt.plot(history_plain_44.history['error_rate'], 'r--', label='PlainNet44 (Train)')
plt.plot(history_plain_44.history['val_error_rate'], 'r-', label='PlainNet44 (Val)')
plt.plot(history_res_44.history['error_rate'], 'g--', label='ResNet44 (Train)')
plt.plot(history_res_44.history['val_error_rate'], 'g-', label='ResNet44 (Val)')

plt.xlabel('Epoch')
plt.ylabel('Error rate (%)')
plt.yticks(np.arange(0, 1, step=0.05))
plt.legend()
plt.show()

# %%
def visualize_results(img_arr, model, layer_names, suptitle=None, figsize=(20,4.5)):
    fig, axes = plt.subplots(1, len(layer_names) + 1, figsize=(20, 4.5))
    axes[0].imshow(img)
    axes[0].set_axis_off()
    idx = 1
    for layer in layer_names:
        heatmap = make_gradcam_heatmap(img_arr, model, layer)
        axes[idx].matshow(heatmap)
        axes[idx].set_axis_off()
        idx += 1
    if suptitle is not None:
        plt.suptitle(suptitle)
    plt.show()

# %%
img = np.mean(x_test, axis=0).astype('uint8')
img_arr = img.reshape((1,32,32,3))

# %%
plainnet44.load_weights("plainnet44_cifar10.tf")
visualize_results(img_arr, model=plainnet44,
                  layer_names=['conv2d', 'conv2d_14', 'conv2d_15', 'conv2d_16',
                               'conv2d_28', 'conv2d_29', 'conv2d_30', 'conv2d_42'])

# %%
resnet44.load_weights("resnet44_cifar10.tf")
visualize_results(img_arr, model=resnet44,
                  layer_names=['conv2d', 'conv2d_14', 'conv2d_16', 'conv2d_17',
                               'conv2d_29', 'conv2d_31', 'conv2d_32', 'conv2d_44'])
